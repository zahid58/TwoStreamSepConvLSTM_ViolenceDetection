# %%
 # proposed model,  both stream

# %%
# !pip install --upgrade tensorflow==2.2  
# !pip install pytorch2keras==0.2.4

# %%
# check gpu
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/4wHdP63A2TXhfAeEezcS8ibw8cllwe6g63clsOJ7Y7XP76G9WYkABJ4

# %%
# !rm -rf sample_data
print('copying violence detection codes')
# !cp -r /gdrive/'My Drive'/THESIS/Data/violenceDetection /content
 
print('extracting rwf2000processed32framesTrainFight.tar')
# !cat /gdrive/'My Drive'/THESIS/Data/data/rwf2000processed32framesTrainFight.tar-* | tar -xvf -
 
print('extracting rwf2000processed32framesTrainNonFight.tar')
# !cat /gdrive/'My Drive'/THESIS/Data/data/rwf2000processed32framesTrainNonFight.tar-* | tar -xvf -
 
print('extracting rwf2000processed32framesTest.tar')
# !tar xvf /gdrive/'My Drive'/THESIS/Data/data/rwf2000processed32framesTest.tar
print('dataset prepared!')
 
#print('copying rwf2000 dataset')
#!cp -r /gdrive/'My Drive'/THESIS/Data/rwf2000 /content/violenceDetection
#%cd violenceDetection
#%cd rwf2000
#print('concatenating three zip files')
#!cat RWF-2000.zip.*>RWF.zip
#print('removing zip file 1')
#!rm -rf RWF-2000.zip.001
#print('removing zip file 2')
#!rm -rf RWF-2000.zip.002
#print('removing zip file 3')
#!rm -rf RWF-2000.zip.003
#print('extracting files')
#!unzip RWF.zip
#print('removing zip file')
#!rm -rf RWF.zip
#print('moving files')
#!mv /content/violenceDetection/rwf2000/RWF-2000/val /content/violenceDetection/rwf2000/RWF-2000/test
#!mv /content/violenceDetection/rwf2000/RWF-2000/test/Fight /content/violenceDetection/rwf2000/RWF-2000/test/fight
#!mv /content/violenceDetection/rwf2000/RWF-2000/test/NonFight /content/violenceDetection/rwf2000/RWF-2000/test/nonFight
#!mv /content/violenceDetection/rwf2000/RWF-2000/train/Fight /content/violenceDetection/rwf2000/RWF-2000/train/fight
#!mv /content/violenceDetection/rwf2000/RWF-2000/train/NonFight /content/violenceDetection/rwf2000/RWF-2000/train/nonFight
#%cd ../..

# %%
# checking if all the videos have been copied succesfully
import os 
print(len(os.listdir('/content/violenceDetection/rwf2000/processed/train/nonFight')))  # should be 800
print(len(os.listdir('/content/violenceDetection/rwf2000/processed/train/fight')))  # should be 800
print(len(os.listdir('/content/violenceDetection/rwf2000/processed/test/nonFight')))  # should be 400
print(len(os.listdir('/content/violenceDetection/rwf2000/processed/test/fight'))) # should be 400
# Out:
# 800
# 800
# 200
# 200

# %%
# convlstm by Sudhakaran et al.   best test accuracy = 86.50%
import os 
os.chdir('/content/violenceDetection')
# !python violenceDetectionRWF.py
# Out:
# Found 1600 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# Found 400 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# > cnn_trainable :  True
# > creating new model... convlstm
# > loading alexnet pytorch model...
# > converting alexnet to keras model...
# Custom shapes isn't supported now.
# 2020-10-01 08:47:20.117775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-01 08:47:20.135225: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:20.135918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-01 08:47:20.135997: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 08:47:20.156103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 08:47:20.252763: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-01 08:47:20.260105: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-01 08:47:20.279741: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-01 08:47:20.286871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-01 08:47:20.375933: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-01 08:47:20.376176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:20.376926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:20.377465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-01 08:47:20.378019: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-01 08:47:20.454574: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2199995000 Hz
# 2020-10-01 08:47:20.455452: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x16b2abc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-01 08:47:20.455487: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-01 08:47:20.566908: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:20.567652: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x16b2ad80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-01 08:47:20.567687: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-01 08:47:20.567969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:20.568535: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-01 08:47:20.568622: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 08:47:20.568668: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 08:47:20.568686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-01 08:47:20.568701: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-01 08:47:20.568717: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-01 08:47:20.568733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-01 08:47:20.568749: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-01 08:47:20.568825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:20.569467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:20.569972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-01 08:47:20.573951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 08:47:30.524017: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-01 08:47:30.524073: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-10-01 08:47:30.524085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-10-01 08:47:30.527839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:30.528530: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 08:47:30.529061: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-01 08:47:30.529105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14320 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# > conversion done...
# > cnn_trainable :  True
# > new model created
# > Summary of the model :
# Model: "model_1"
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# frames_input (InputLayer)                                      [(None, 31, 224, 224, 3)]                               0
# ____________________________________________________________________________________________________________________________________________
# frames_CNN (TimeDistributed)                                   (None, 31, 6, 6, 256)                                   2469696
# ____________________________________________________________________________________________________________________________________________
# ConvLSTM2D_ (ConvLSTM2D)                                       (None, 6, 6, 256)                                       4719616
# ____________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                                   (None, 3, 3, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten (Flatten)                                              (None, 2304)                                            0
# ____________________________________________________________________________________________________________________________________________
# dense (Dense)                                                  (None, 1000)                                            2305000
# ____________________________________________________________________________________________________________________________________________
# batch_normalization (BatchNormalization)                       (None, 1000)                                            4000
# ____________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                                (None, 256)                                             256256
# ____________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                                (None, 10)                                              2570
# ____________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                                (None, 2)                                               22
# ============================================================================================================================================
# Total params: 9,757,160
# Trainable params: 9,755,160
# Non-trainable params: 2,000
# ____________________________________________________________________________________________________________________________________________
# > Optimizer :  {'name': 'Adam', 'learning_rate': 1e-05, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': True}
# > plotting the model architecture and saving at  model_architecture.png
# Epoch 1/50
# 2020-10-01 08:47:45.952676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 08:47:56.881856: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 400/400 [==============================] - 589s 1s/step - loss: 0.7248 - acc: 0.5981 - val_loss: 0.5763 - val_acc: 0.7000
# Epoch 2/50
# 400/400 [==============================] - 577s 1s/step - loss: 0.6594 - acc: 0.6475 - val_loss: 0.5846 - val_acc: 0.6900
# Epoch 3/50
# 400/400 [==============================] - 570s 1s/step - loss: 0.6295 - acc: 0.6700 - val_loss: 0.5756 - val_acc: 0.6675
# Epoch 4/50
# 400/400 [==============================] - 569s 1s/step - loss: 0.6299 - acc: 0.6581 - val_loss: 0.5505 - val_acc: 0.7200
# Epoch 5/50
# 400/400 [==============================] - 558s 1s/step - loss: 0.6296 - acc: 0.6662 - val_loss: 0.5515 - val_acc: 0.7450
# Epoch 6/50
# 400/400 [==============================] - 559s 1s/step - loss: 0.6101 - acc: 0.6919 - val_loss: 0.5584 - val_acc: 0.7100
# Epoch 7/50
# 400/400 [==============================] - 575s 1s/step - loss: 0.5958 - acc: 0.7044 - val_loss: 0.5509 - val_acc: 0.7225
# Epoch 8/50
# 400/400 [==============================] - 575s 1s/step - loss: 0.5876 - acc: 0.6919 - val_loss: 0.5362 - val_acc: 0.7375
# Epoch 9/50
# 400/400 [==============================] - 564s 1s/step - loss: 0.6019 - acc: 0.6862 - val_loss: 0.5292 - val_acc: 0.7400
# Epoch 10/50
# 400/400 [==============================] - 562s 1s/step - loss: 0.5863 - acc: 0.6969 - val_loss: 0.5228 - val_acc: 0.7425
# Epoch 11/50
# 400/400 [==============================] - 569s 1s/step - loss: 0.5839 - acc: 0.7044 - val_loss: 0.5268 - val_acc: 0.7575
# Epoch 12/50
# 400/400 [==============================] - 565s 1s/step - loss: 0.5781 - acc: 0.7056 - val_loss: 0.5453 - val_acc: 0.7350
# Epoch 13/50
# 400/400 [==============================] - 579s 1s/step - loss: 0.5778 - acc: 0.7050 - val_loss: 0.5271 - val_acc: 0.7600
# Epoch 14/50
# 400/400 [==============================] - 561s 1s/step - loss: 0.5513 - acc: 0.7237 - val_loss: 0.5189 - val_acc: 0.7400
# Epoch 15/50
# 400/400 [==============================] - 566s 1s/step - loss: 0.5782 - acc: 0.7163 - val_loss: 0.5121 - val_acc: 0.7675
# Epoch 16/50
# 400/400 [==============================] - 563s 1s/step - loss: 0.5545 - acc: 0.7200 - val_loss: 0.5062 - val_acc: 0.7625
# Epoch 17/50
# 400/400 [==============================] - 564s 1s/step - loss: 0.5515 - acc: 0.7219 - val_loss: 0.5190 - val_acc: 0.7650
# Epoch 18/50
# 400/400 [==============================] - 562s 1s/step - loss: 0.5406 - acc: 0.7262 - val_loss: 0.4936 - val_acc: 0.7775
# Epoch 19/50
# 400/400 [==============================] - 569s 1s/step - loss: 0.5601 - acc: 0.7156 - val_loss: 0.5433 - val_acc: 0.7300
# Epoch 20/50
# 400/400 [==============================] - 572s 1s/step - loss: 0.5445 - acc: 0.7231 - val_loss: 0.5401 - val_acc: 0.7425
# Epoch 21/50
# 400/400 [==============================] - 561s 1s/step - loss: 0.5472 - acc: 0.7237 - val_loss: 0.5101 - val_acc: 0.7800
# Epoch 22/50
# 400/400 [==============================] - 570s 1s/step - loss: 0.5527 - acc: 0.7225 - val_loss: 0.5266 - val_acc: 0.7425
# Epoch 23/50
# 400/400 [==============================] - 566s 1s/step - loss: 0.5333 - acc: 0.7300 - val_loss: 0.5005 - val_acc: 0.7650
# Epoch 24/50
# 400/400 [==============================] - 569s 1s/step - loss: 0.5406 - acc: 0.7419 - val_loss: 0.5083 - val_acc: 0.7425
# Epoch 25/50
# 400/400 [==============================] - 562s 1s/step - loss: 0.5254 - acc: 0.7412 - val_loss: 0.4957 - val_acc: 0.7675
# Epoch 26/50
# 400/400 [==============================] - 562s 1s/step - loss: 0.5270 - acc: 0.7444 - val_loss: 0.5136 - val_acc: 0.7725
# Epoch 27/50
# 400/400 [==============================] - 573s 1s/step - loss: 0.5093 - acc: 0.7469 - val_loss: 0.4994 - val_acc: 0.7775
# Epoch 28/50
# 400/400 [==============================] - 570s 1s/step - loss: 0.5087 - acc: 0.7475 - val_loss: 0.4620 - val_acc: 0.7900
# Epoch 29/50
# 399/400 [============================>.] - ETA: 1s - loss: 0.5091 - acc: 0.7732

# %%
import os 
os.chdir('/content/violenceDetection')
# !python violenceDetectionRWF.py
# Out:
# Found 1600 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# Found 400 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# > cnn_trainable :  True
# > getting the model from... /gdrive/My Drive/THESIS/Data/rwf2000_currentModel.h5
# 2020-10-01 13:59:05.335098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-01 13:59:05.339042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:05.339633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-01 13:59:05.339686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 13:59:05.359272: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 13:59:05.372562: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-01 13:59:05.383209: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-01 13:59:05.400547: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-01 13:59:05.417091: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-01 13:59:05.445525: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-01 13:59:05.445702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:05.446329: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:05.446843: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-01 13:59:05.447163: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-01 13:59:05.453129: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-10-01 13:59:05.453427: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x64dd9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-01 13:59:05.453459: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-01 13:59:05.566555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:05.567214: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x64dd800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-01 13:59:05.567254: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-01 13:59:05.567594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:05.568126: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-01 13:59:05.568193: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 13:59:05.568250: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 13:59:05.568280: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-01 13:59:05.568307: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-01 13:59:05.568334: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-01 13:59:05.568359: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-01 13:59:05.568401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-01 13:59:05.568499: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:05.569074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:05.569566: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-01 13:59:05.569654: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 13:59:14.809457: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-01 13:59:14.809519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-10-01 13:59:14.809538: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-10-01 13:59:14.809832: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:14.810424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 13:59:14.810925: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-01 13:59:14.810965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14320 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# > Summary of the model :
# Model: "model_1"
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# frames_input (InputLayer)                                      [(None, 31, 224, 224, 3)]                               0
# ____________________________________________________________________________________________________________________________________________
# frames_CNN (TimeDistributed)                                   (None, 31, 6, 6, 256)                                   2469696
# ____________________________________________________________________________________________________________________________________________
# ConvLSTM2D_ (ConvLSTM2D)                                       (None, 6, 6, 256)                                       4719616
# ____________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                                   (None, 3, 3, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten (Flatten)                                              (None, 2304)                                            0
# ____________________________________________________________________________________________________________________________________________
# dense (Dense)                                                  (None, 1000)                                            2305000
# ____________________________________________________________________________________________________________________________________________
# batch_normalization (BatchNormalization)                       (None, 1000)                                            4000
# ____________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                                (None, 256)                                             256256
# ____________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                                (None, 10)                                              2570
# ____________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                                (None, 2)                                               22
# ============================================================================================================================================
# Total params: 9,757,160
# Trainable params: 9,755,160
# Non-trainable params: 2,000
# ____________________________________________________________________________________________________________________________________________
# > Optimizer :  {'name': 'Adam', 'learning_rate': 1e-05, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': True}
# > plotting the model architecture and saving at  model_architecture.png
# Epoch 1/70
# 2020-10-01 14:00:29.396875: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 14:00:39.607949: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 400/400 [==============================] - 594s 1s/step - loss: 0.5064 - acc: 0.7663 - val_loss: 0.4580 - val_acc: 0.7800
# Epoch 2/70
# 400/400 [==============================] - 573s 1s/step - loss: 0.5149 - acc: 0.7475 - val_loss: 0.4500 - val_acc: 0.8000
# Epoch 3/70
# 400/400 [==============================] - 560s 1s/step - loss: 0.4821 - acc: 0.7638 - val_loss: 0.4460 - val_acc: 0.7875
# Epoch 4/70
# 400/400 [==============================] - 562s 1s/step - loss: 0.4950 - acc: 0.7663 - val_loss: 0.4578 - val_acc: 0.7875
# Epoch 5/70
# 400/400 [==============================] - 570s 1s/step - loss: 0.5021 - acc: 0.7544 - val_loss: 0.4784 - val_acc: 0.7900
# Epoch 6/70
# 400/400 [==============================] - 563s 1s/step - loss: 0.5021 - acc: 0.7487 - val_loss: 0.4527 - val_acc: 0.8025
# Epoch 7/70
# 400/400 [==============================] - 561s 1s/step - loss: 0.4821 - acc: 0.7719 - val_loss: 0.4508 - val_acc: 0.7900
# Epoch 8/70
# 400/400 [==============================] - 558s 1s/step - loss: 0.4889 - acc: 0.7731 - val_loss: 0.4867 - val_acc: 0.7850
# Epoch 9/70
# 400/400 [==============================] - 562s 1s/step - loss: 0.5007 - acc: 0.7575 - val_loss: 0.4577 - val_acc: 0.7825
# Epoch 10/70
# 400/400 [==============================] - 563s 1s/step - loss: 0.4809 - acc: 0.7675 - val_loss: 0.4337 - val_acc: 0.7900
# Epoch 11/70
# 400/400 [==============================] - 561s 1s/step - loss: 0.4739 - acc: 0.7631 - val_loss: 0.4301 - val_acc: 0.8000
# Epoch 12/70
# 400/400 [==============================] - 563s 1s/step - loss: 0.4749 - acc: 0.7775 - val_loss: 0.4482 - val_acc: 0.8000
# Epoch 13/70
# 400/400 [==============================] - 577s 1s/step - loss: 0.4572 - acc: 0.7937 - val_loss: 0.4438 - val_acc: 0.8125
# Epoch 14/70
# 400/400 [==============================] - 567s 1s/step - loss: 0.4599 - acc: 0.7937 - val_loss: 0.4292 - val_acc: 0.8150
# Epoch 15/70
# 400/400 [==============================] - 562s 1s/step - loss: 0.4675 - acc: 0.7706 - val_loss: 0.4240 - val_acc: 0.8125
# Epoch 16/70
# 400/400 [==============================] - 569s 1s/step - loss: 0.4765 - acc: 0.7788 - val_loss: 0.4219 - val_acc: 0.8050
# Epoch 17/70
# 400/400 [==============================] - 556s 1s/step - loss: 0.4582 - acc: 0.7806 - val_loss: 0.4140 - val_acc: 0.8175
# Epoch 18/70
# 400/400 [==============================] - 576s 1s/step - loss: 0.4548 - acc: 0.7800 - val_loss: 0.4592 - val_acc: 0.8025
# Epoch 19/70
# 400/400 [==============================] - 566s 1s/step - loss: 0.4545 - acc: 0.7844 - val_loss: 0.4256 - val_acc: 0.8125
# Epoch 20/70
# 400/400 [==============================] - 566s 1s/step - loss: 0.4524 - acc: 0.7962 - val_loss: 0.4305 - val_acc: 0.8175
# Epoch 21/70
# 400/400 [==============================] - 580s 1s/step - loss: 0.4470 - acc: 0.7987 - val_loss: 0.4260 - val_acc: 0.8225
# Epoch 22/70
# 400/400 [==============================] - 557s 1s/step - loss: 0.4481 - acc: 0.7969 - val_loss: 0.4564 - val_acc: 0.8300
# Epoch 23/70
# 400/400 [==============================] - 568s 1s/step - loss: 0.4332 - acc: 0.8031 - val_loss: 0.4400 - val_acc: 0.8200
# Epoch 24/70
# 400/400 [==============================] - 566s 1s/step - loss: 0.4210 - acc: 0.8125 - val_loss: 0.4017 - val_acc: 0.8200
# Epoch 25/70
# 400/400 [==============================] - 566s 1s/step - loss: 0.4173 - acc: 0.8062 - val_loss: 0.4426 - val_acc: 0.8075
# Epoch 26/70
# 400/400 [==============================] - 573s 1s/step - loss: 0.4478 - acc: 0.8012 - val_loss: 0.3981 - val_acc: 0.8225
# Epoch 27/70
# 400/400 [==============================] - 569s 1s/step - loss: 0.4344 - acc: 0.8050 - val_loss: 0.3845 - val_acc: 0.8425
# Epoch 28/70
# 400/400 [==============================] - 566s 1s/step - loss: 0.4409 - acc: 0.7944 - val_loss: 0.4025 - val_acc: 0.8275
# Epoch 29/70
# 400/400 [==============================] - 557s 1s/step - loss: 0.4360 - acc: 0.7994 - val_loss: 0.4015 - val_acc: 0.8350
# Epoch 30/70
# 400/400 [==============================] - 565s 1s/step - loss: 0.4336 - acc: 0.8037 - val_loss: 0.4054 - val_acc: 0.8450
# Epoch 31/70
#  99/400 [======>.......................] - ETA: 5:24 - loss: 0.4418 - acc: 0.7854

# %%
import os 
os.chdir('/content/violenceDetection')
# !python violenceDetectionRWF.py
# Out:
# Found 1600 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# Found 400 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# > cnn_trainable :  True
# > getting the model from... /gdrive/My Drive/THESIS/Data/rwf2000_currentModel.h5
# 2020-10-01 18:51:23.240742: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-01 18:51:23.303645: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:23.304230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-01 18:51:23.304304: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 18:51:23.536242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 18:51:23.695931: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-01 18:51:23.714824: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-01 18:51:23.982404: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-01 18:51:24.011900: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-01 18:51:24.525914: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-01 18:51:24.526133: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:24.526818: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:24.527322: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-01 18:51:24.527869: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-01 18:51:24.577212: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-10-01 18:51:24.577765: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6aaf9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-01 18:51:24.577792: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-01 18:51:24.700195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:24.700849: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6aaf800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-01 18:51:24.700884: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-01 18:51:24.701102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:24.701647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-01 18:51:24.701703: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 18:51:24.701739: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 18:51:24.701755: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-01 18:51:24.701770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-01 18:51:24.701784: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-01 18:51:24.701798: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-01 18:51:24.701814: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-01 18:51:24.701884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:24.702400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:24.702881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-01 18:51:24.705660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-01 18:51:33.897854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-01 18:51:33.897916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-10-01 18:51:33.897950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-10-01 18:51:33.902232: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:33.902905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-01 18:51:33.903414: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-01 18:51:33.903456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14560 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# > Summary of the model :
# Model: "model_1"
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# frames_input (InputLayer)                                      [(None, 31, 224, 224, 3)]                               0
# ____________________________________________________________________________________________________________________________________________
# frames_CNN (TimeDistributed)                                   (None, 31, 6, 6, 256)                                   2469696
# ____________________________________________________________________________________________________________________________________________
# ConvLSTM2D_ (ConvLSTM2D)                                       (None, 6, 6, 256)                                       4719616
# ____________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                                   (None, 3, 3, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten (Flatten)                                              (None, 2304)                                            0
# ____________________________________________________________________________________________________________________________________________
# dense (Dense)                                                  (None, 1000)                                            2305000
# ____________________________________________________________________________________________________________________________________________
# batch_normalization (BatchNormalization)                       (None, 1000)                                            4000
# ____________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                                (None, 256)                                             256256
# ____________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                                (None, 10)                                              2570
# ____________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                                (None, 2)                                               22
# ============================================================================================================================================
# Total params: 9,757,160
# Trainable params: 9,755,160
# Non-trainable params: 2,000
# ____________________________________________________________________________________________________________________________________________
# > Optimizer :  {'name': 'Adam', 'learning_rate': 1e-05, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': True}
# > plotting the model architecture and saving at  model_architecture.png
# Epoch 1/70
# 2020-10-01 18:51:59.982597: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-01 18:52:10.342929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 400/400 [==============================] - 587s 1s/step - loss: 0.4265 - acc: 0.8119 - val_loss: 0.3870 - val_acc: 0.8250
# Epoch 2/70
# 400/400 [==============================] - 574s 1s/step - loss: 0.4082 - acc: 0.8194 - val_loss: 0.3864 - val_acc: 0.8325
# Epoch 3/70
# 400/400 [==============================] - 573s 1s/step - loss: 0.4108 - acc: 0.8269 - val_loss: 0.4004 - val_acc: 0.8550
# Epoch 4/70
# 400/400 [==============================] - 577s 1s/step - loss: 0.4401 - acc: 0.7900 - val_loss: 0.3874 - val_acc: 0.8300
# Epoch 5/70
# 400/400 [==============================] - 570s 1s/step - loss: 0.4074 - acc: 0.8181 - val_loss: 0.4485 - val_acc: 0.8350
# Epoch 6/70
# 400/400 [==============================] - 570s 1s/step - loss: 0.3983 - acc: 0.8263 - val_loss: 0.4032 - val_acc: 0.8450
# Epoch 7/70
# 400/400 [==============================] - 568s 1s/step - loss: 0.4113 - acc: 0.8256 - val_loss: 0.4108 - val_acc: 0.8350
# Epoch 8/70
# 400/400 [==============================] - 566s 1s/step - loss: 0.4065 - acc: 0.8188 - val_loss: 0.3807 - val_acc: 0.8375
# Epoch 9/70
# 400/400 [==============================] - 565s 1s/step - loss: 0.4022 - acc: 0.8294 - val_loss: 0.4207 - val_acc: 0.8375
# Epoch 10/70
# 400/400 [==============================] - 564s 1s/step - loss: 0.4111 - acc: 0.8169 - val_loss: 0.3720 - val_acc: 0.8300
# Epoch 11/70
# 400/400 [==============================] - 556s 1s/step - loss: 0.4040 - acc: 0.8275 - val_loss: 0.3877 - val_acc: 0.8250
# Epoch 12/70
# 400/400 [==============================] - 562s 1s/step - loss: 0.3838 - acc: 0.8325 - val_loss: 0.3762 - val_acc: 0.8325
# Epoch 13/70
# 400/400 [==============================] - 556s 1s/step - loss: 0.4011 - acc: 0.8306 - val_loss: 0.4259 - val_acc: 0.8325
# Epoch 14/70
# 400/400 [==============================] - 564s 1s/step - loss: 0.3957 - acc: 0.8156 - val_loss: 0.3968 - val_acc: 0.8575
# Epoch 15/70
# 400/400 [==============================] - 556s 1s/step - loss: 0.4263 - acc: 0.8050 - val_loss: 0.3773 - val_acc: 0.8500
# Epoch 16/70
# 400/400 [==============================] - 559s 1s/step - loss: 0.3794 - acc: 0.8450 - val_loss: 0.4465 - val_acc: 0.8575
# Epoch 17/70
# 400/400 [==============================] - 561s 1s/step - loss: 0.3860 - acc: 0.8325 - val_loss: 0.5071 - val_acc: 0.8275
# Epoch 18/70
# 400/400 [==============================] - 557s 1s/step - loss: 0.3969 - acc: 0.8269 - val_loss: 0.3937 - val_acc: 0.8550
# Epoch 19/70
# 400/400 [==============================] - 557s 1s/step - loss: 0.4014 - acc: 0.8163 - val_loss: 0.4056 - val_acc: 0.8275
# Epoch 20/70
# 400/400 [==============================] - 569s 1s/step - loss: 0.3936 - acc: 0.8269 - val_loss: 0.4944 - val_acc: 0.8075
# Epoch 21/70
# 400/400 [==============================] - 565s 1s/step - loss: 0.3991 - acc: 0.8231 - val_loss: 0.4647 - val_acc: 0.8225
# Epoch 22/70
# 400/400 [==============================] - 571s 1s/step - loss: 0.3888 - acc: 0.8331 - val_loss: 0.4008 - val_acc: 0.8400
# Epoch 23/70
# 400/400 [==============================] - 562s 1s/step - loss: 0.4006 - acc: 0.8213 - val_loss: 0.4605 - val_acc: 0.8525
# Epoch 24/70
# 400/400 [==============================] - 565s 1s/step - loss: 0.4011 - acc: 0.8125 - val_loss: 0.4252 - val_acc: 0.8375
# Epoch 25/70
# 400/400 [==============================] - 574s 1s/step - loss: 0.3836 - acc: 0.8313 - val_loss: 0.4273 - val_acc: 0.8300
# Epoch 26/70
# 400/400 [==============================] - 564s 1s/step - loss: 0.3673 - acc: 0.8475 - val_loss: 0.4359 - val_acc: 0.8250
# Epoch 27/70
# 400/400 [==============================] - 574s 1s/step - loss: 0.3855 - acc: 0.8381 - val_loss: 0.4440 - val_acc: 0.8600
# Epoch 28/70
# 400/400 [==============================] - 571s 1s/step - loss: 0.3906 - acc: 0.8269 - val_loss: 0.3895 - val_acc: 0.8450
# Epoch 29/70
# 400/400 [==============================] - 565s 1s/step - loss: 0.3848 - acc: 0.8306 - val_loss: 0.3823 - val_acc: 0.8450
# Epoch 30/70
# 400/400 [==============================] - ETA: 0s - loss: 0.3705 - acc: 0.8544

# %%
import os 
os.chdir('/content/violenceDetection')
# !python violenceDetectionRWF.py
# Out:
# Found 1600 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# Found 400 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# > cnn_trainable :  True
# > getting the model from... /gdrive/My Drive/THESIS/Data/rwf2000_currentModel.h5
# 2020-10-02 03:12:30.324325: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-02 03:12:30.339387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:30.339924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-02 03:12:30.339976: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 03:12:30.359753: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 03:12:30.368806: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-02 03:12:30.375305: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-02 03:12:30.394164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-02 03:12:30.410407: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-02 03:12:30.442069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-02 03:12:30.442213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:30.442799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:30.443303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-02 03:12:30.443605: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-02 03:12:30.448720: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-10-02 03:12:30.449036: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x603d9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-02 03:12:30.449084: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-02 03:12:30.552505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:30.553163: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x603d800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-02 03:12:30.553194: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-02 03:12:30.553462: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:30.553965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-02 03:12:30.554042: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 03:12:30.554083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 03:12:30.554120: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-02 03:12:30.554132: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-02 03:12:30.554147: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-02 03:12:30.554161: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-02 03:12:30.554176: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-02 03:12:30.554246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:30.554775: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:30.555262: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-02 03:12:30.555328: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 03:12:39.692687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-02 03:12:39.692743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-10-02 03:12:39.692752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-10-02 03:12:39.693022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:39.693612: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 03:12:39.694161: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-02 03:12:39.694199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14560 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# > Summary of the model :
# Model: "model_1"
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# frames_input (InputLayer)                                      [(None, 31, 224, 224, 3)]                               0
# ____________________________________________________________________________________________________________________________________________
# frames_CNN (TimeDistributed)                                   (None, 31, 6, 6, 256)                                   2469696
# ____________________________________________________________________________________________________________________________________________
# ConvLSTM2D_ (ConvLSTM2D)                                       (None, 6, 6, 256)                                       4719616
# ____________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                                   (None, 3, 3, 256)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten (Flatten)                                              (None, 2304)                                            0
# ____________________________________________________________________________________________________________________________________________
# dense (Dense)                                                  (None, 1000)                                            2305000
# ____________________________________________________________________________________________________________________________________________
# batch_normalization (BatchNormalization)                       (None, 1000)                                            4000
# ____________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                                (None, 256)                                             256256
# ____________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                                (None, 10)                                              2570
# ____________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                                (None, 2)                                               22
# ============================================================================================================================================
# Total params: 9,757,160
# Trainable params: 9,755,160
# Non-trainable params: 2,000
# ____________________________________________________________________________________________________________________________________________
# > Optimizer :  {'name': 'Adam', 'learning_rate': 1e-05, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': True}
# > plotting the model architecture and saving at  model_architecture.png
# Epoch 1/50
# 2020-10-02 03:12:58.289688: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 03:13:07.658396: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 400/400 [==============================] - 593s 1s/step - loss: 0.3666 - acc: 0.8363 - val_loss: 0.4218 - val_acc: 0.8425
# Epoch 2/50
# 400/400 [==============================] - 573s 1s/step - loss: 0.3714 - acc: 0.8400 - val_loss: 0.3982 - val_acc: 0.8400
# Epoch 3/50
# 400/400 [==============================] - 563s 1s/step - loss: 0.3912 - acc: 0.8306 - val_loss: 0.3940 - val_acc: 0.8350
# Epoch 4/50
# 400/400 [==============================] - 559s 1s/step - loss: 0.3700 - acc: 0.8456 - val_loss: 0.3992 - val_acc: 0.8475
# Epoch 5/50
# 400/400 [==============================] - 554s 1s/step - loss: 0.3634 - acc: 0.8456 - val_loss: 0.3802 - val_acc: 0.8425
# Epoch 6/50
# 400/400 [==============================] - 562s 1s/step - loss: 0.3391 - acc: 0.8550 - val_loss: 0.3912 - val_acc: 0.8475
# Epoch 7/50
# 400/400 [==============================] - 560s 1s/step - loss: 0.3403 - acc: 0.8581 - val_loss: 0.3692 - val_acc: 0.8400
# Epoch 8/50
# 400/400 [==============================] - 558s 1s/step - loss: 0.3708 - acc: 0.8469 - val_loss: 0.4500 - val_acc: 0.8350
# Epoch 9/50
# 400/400 [==============================] - 561s 1s/step - loss: 0.3466 - acc: 0.8519 - val_loss: 0.3962 - val_acc: 0.8325
# Epoch 10/50
# 400/400 [==============================] - 550s 1s/step - loss: 0.3608 - acc: 0.8481 - val_loss: 0.4571 - val_acc: 0.8300
# Epoch 11/50
# 400/400 [==============================] - 550s 1s/step - loss: 0.3539 - acc: 0.8456 - val_loss: 0.3533 - val_acc: 0.8525
# Epoch 12/50
# 400/400 [==============================] - 561s 1s/step - loss: 0.3599 - acc: 0.8425 - val_loss: 0.3800 - val_acc: 0.8325
# Epoch 13/50
# 400/400 [==============================] - 555s 1s/step - loss: 0.3568 - acc: 0.8431 - val_loss: 0.4206 - val_acc: 0.8325
# Epoch 14/50
# 400/400 [==============================] - 562s 1s/step - loss: 0.3453 - acc: 0.8556 - val_loss: 0.4610 - val_acc: 0.8350
# Epoch 15/50
# 400/400 [==============================] - 560s 1s/step - loss: 0.3615 - acc: 0.8338 - val_loss: 0.3993 - val_acc: 0.8275
# Epoch 16/50
# 400/400 [==============================] - 563s 1s/step - loss: 0.3584 - acc: 0.8612 - val_loss: 0.4047 - val_acc: 0.8400
# Epoch 17/50
# 400/400 [==============================] - 568s 1s/step - loss: 0.3587 - acc: 0.8556 - val_loss: 0.4863 - val_acc: 0.8450
# Epoch 18/50
# 400/400 [==============================] - 561s 1s/step - loss: 0.3454 - acc: 0.8519 - val_loss: 0.4454 - val_acc: 0.8350
# Epoch 19/50
# 400/400 [==============================] - 556s 1s/step - loss: 0.3551 - acc: 0.8450 - val_loss: 0.4159 - val_acc: 0.8350
# Epoch 20/50
# 400/400 [==============================] - 569s 1s/step - loss: 0.3592 - acc: 0.8475 - val_loss: 0.4349 - val_acc: 0.8450
# Epoch 21/50
# 400/400 [==============================] - 560s 1s/step - loss: 0.3418 - acc: 0.8531 - val_loss: 0.4477 - val_acc: 0.8500
# Epoch 22/50
# 400/400 [==============================] - 555s 1s/step - loss: 0.3361 - acc: 0.8625 - val_loss: 0.4109 - val_acc: 0.8650
# Epoch 23/50
# 400/400 [==============================] - 560s 1s/step - loss: 0.3233 - acc: 0.8544 - val_loss: 0.4595 - val_acc: 0.8575
# Epoch 24/50
# 400/400 [==============================] - 567s 1s/step - loss: 0.3282 - acc: 0.8631 - val_loss: 0.4375 - val_acc: 0.8400
# Epoch 25/50
#  34/400 [=>............................] - ETA: 6:34 - loss: 0.3282 - acc: 0.8456

# %%
# biconvlstm by Hanson et al.     best test accuracy = 86.75%
import os 
os.chdir('/content/violenceDetection')
# !python violenceDetectionRWF.py
# Out:
# Found 1600 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# Found 400 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# > cnn_trainable :  True
# > creating new model... biconvlstm
# > loading VGG13 pytorch model...
# Downloading: "https://download.pytorch.org/models/vgg13-c768596a.pth" to /root/.cache/torch/hub/checkpoints/vgg13-c768596a.pth
# 100% 508M/508M [00:04<00:00, 129MB/s]
# > converting VGG13 to keras model...
# Custom shapes isn't supported now.
# 2020-10-02 07:09:06.040015: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-02 07:09:06.052140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:06.052681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-02 07:09:06.052745: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 07:09:06.054403: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 07:09:06.055971: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-02 07:09:06.056363: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-02 07:09:06.057975: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-02 07:09:06.058727: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-02 07:09:06.061951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-02 07:09:06.062105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:06.062657: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:06.063204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-02 07:09:06.063458: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-02 07:09:06.068142: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-10-02 07:09:06.068609: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8315880 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-02 07:09:06.068643: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-02 07:09:06.147835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:06.148479: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8315a40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-02 07:09:06.148521: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-02 07:09:06.148763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:06.149326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-02 07:09:06.149401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 07:09:06.149464: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 07:09:06.149491: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-02 07:09:06.149521: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-02 07:09:06.149545: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-02 07:09:06.149568: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-02 07:09:06.149591: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-02 07:09:06.149676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:06.150335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:06.150819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-02 07:09:06.150890: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 07:09:11.698286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-02 07:09:11.698340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-10-02 07:09:11.698348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-10-02 07:09:11.702601: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:11.703262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 07:09:11.703801: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-02 07:09:11.703838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14560 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# Unable to use `same` padding. Add ZeroPadding2D layer to fix shapes.
# > conversion done...
# > cnn_trainable :  True
# > new model created
# > Summary of the model :
# Model: "model_1"
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# frames_input (InputLayer)                                      [(None, 31, 224, 224, 3)]                               0
# ____________________________________________________________________________________________________________________________________________
# frames_CNN (TimeDistributed)                                   (None, 31, 14, 14, 512)                                 9404992
# ____________________________________________________________________________________________________________________________________________
# bidirectional (Bidirectional)                                  (None, 31, 14, 14, 512)                                 14157824
# ____________________________________________________________________________________________________________________________________________
# ElementWiseMaxPooling (Lambda)                                 (None, 14, 14, 512)                                     0
# ____________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                                   (None, 7, 7, 512)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten (Flatten)                                              (None, 25088)                                           0
# ____________________________________________________________________________________________________________________________________________
# dense (Dense)                                                  (None, 1000)                                            25089000
# ____________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                                (None, 256)                                             256256
# ____________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                                (None, 10)                                              2570
# ____________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                                (None, 2)                                               22
# ============================================================================================================================================
# Total params: 48,910,664
# Trainable params: 48,910,664
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________
# > Optimizer :  {'name': 'Adam', 'learning_rate': 1e-06, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': True}
# > plotting the model architecture and saving at  model_architecture.png
# Epoch 1/50
# 2020-10-02 07:09:31.340284: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 07:09:36.063455: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 800/800 [==============================] - 779s 974ms/step - loss: 0.6407 - acc: 0.6587 - val_loss: 0.5209 - val_acc: 0.7525
# Epoch 2/50
# 800/800 [==============================] - 771s 964ms/step - loss: 0.5748 - acc: 0.7300 - val_loss: 0.4715 - val_acc: 0.7875
# Epoch 3/50
# 800/800 [==============================] - 765s 956ms/step - loss: 0.5449 - acc: 0.7431 - val_loss: 0.4429 - val_acc: 0.7950
# Epoch 4/50
# 800/800 [==============================] - 766s 958ms/step - loss: 0.5380 - acc: 0.7563 - val_loss: 0.4298 - val_acc: 0.8000
# Epoch 5/50
# 800/800 [==============================] - 764s 955ms/step - loss: 0.5079 - acc: 0.7788 - val_loss: 0.4258 - val_acc: 0.7975
# Epoch 6/50
# 800/800 [==============================] - 775s 968ms/step - loss: 0.4971 - acc: 0.7837 - val_loss: 0.4164 - val_acc: 0.8100
# Epoch 7/50
# 800/800 [==============================] - 775s 969ms/step - loss: 0.4776 - acc: 0.7919 - val_loss: 0.4179 - val_acc: 0.8275
# Epoch 8/50
# 800/800 [==============================] - 773s 967ms/step - loss: 0.4648 - acc: 0.7937 - val_loss: 0.3996 - val_acc: 0.8075
# Epoch 9/50
# 800/800 [==============================] - 775s 969ms/step - loss: 0.4556 - acc: 0.8075 - val_loss: 0.3982 - val_acc: 0.8025
# Epoch 10/50
# 800/800 [==============================] - 778s 973ms/step - loss: 0.4499 - acc: 0.8112 - val_loss: 0.4048 - val_acc: 0.8025
# Epoch 11/50
# 800/800 [==============================] - 776s 970ms/step - loss: 0.4446 - acc: 0.8100 - val_loss: 0.3779 - val_acc: 0.8250
# Epoch 12/50
# 800/800 [==============================] - 783s 978ms/step - loss: 0.4185 - acc: 0.8338 - val_loss: 0.3664 - val_acc: 0.8250
# Epoch 13/50
# 800/800 [==============================] - 778s 972ms/step - loss: 0.4323 - acc: 0.8163 - val_loss: 0.3701 - val_acc: 0.8225
# Epoch 14/50
# 800/800 [==============================] - 775s 969ms/step - loss: 0.4176 - acc: 0.8338 - val_loss: 0.3556 - val_acc: 0.8375
# Epoch 15/50
# 800/800 [==============================] - 779s 973ms/step - loss: 0.4170 - acc: 0.8288 - val_loss: 0.3587 - val_acc: 0.8350
# Epoch 16/50
# 800/800 [==============================] - 776s 970ms/step - loss: 0.4018 - acc: 0.8413 - val_loss: 0.3464 - val_acc: 0.8425
# Epoch 17/50
# 800/800 [==============================] - 778s 973ms/step - loss: 0.3975 - acc: 0.8413 - val_loss: 0.3642 - val_acc: 0.8250
# Epoch 18/50
# 800/800 [==============================] - 771s 964ms/step - loss: 0.3949 - acc: 0.8438 - val_loss: 0.3500 - val_acc: 0.8475
# Epoch 19/50
# 800/800 [==============================] - 774s 968ms/step - loss: 0.3706 - acc: 0.8575 - val_loss: 0.3411 - val_acc: 0.8475
# Epoch 20/50
# 800/800 [==============================] - 773s 966ms/step - loss: 0.3678 - acc: 0.8550 - val_loss: 0.3311 - val_acc: 0.8550
# Epoch 21/50
# 800/800 [==============================] - 774s 968ms/step - loss: 0.3680 - acc: 0.8669 - val_loss: 0.3614 - val_acc: 0.8425
# Epoch 22/50
# 800/800 [==============================] - 780s 975ms/step - loss: 0.3630 - acc: 0.8581 - val_loss: 0.3278 - val_acc: 0.8600
# Epoch 23/50
# 800/800 [==============================] - 777s 971ms/step - loss: 0.3535 - acc: 0.8587 - val_loss: 0.3342 - val_acc: 0.8575
# Epoch 24/50
# 800/800 [==============================] - 781s 976ms/step - loss: 0.3580 - acc: 0.8669 - val_loss: 0.3312 - val_acc: 0.8600
# Epoch 25/50
# 800/800 [==============================] - 778s 972ms/step - loss: 0.3487 - acc: 0.8669 - val_loss: 0.4015 - val_acc: 0.8175
# Epoch 26/50
# 800/800 [==============================] - ETA: 0s - loss: 0.3493 - acc: 0.8662

# %%
import os 
os.chdir('/content/violenceDetection')
# !python violenceDetectionRWF.py
# Out:
# Found 1600 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# Found 400 files belonging to 2 classes.
#      fight :  0
#   nonFight :  1
# > cnn_trainable :  True
# > getting the model from... /gdrive/My Drive/THESIS/Data/rwf2000_currentModel.h5
# 2020-10-02 14:40:06.735226: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-02 14:40:06.738845: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:06.739759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-02 14:40:06.739817: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 14:40:06.752957: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 14:40:06.759201: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-02 14:40:06.766965: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-02 14:40:06.778988: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-02 14:40:06.783734: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-02 14:40:06.799256: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-02 14:40:06.799438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:06.800441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:06.801265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-02 14:40:06.801577: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-10-02 14:40:06.807562: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-10-02 14:40:06.807937: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x64719c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-02 14:40:06.807982: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-02 14:40:06.914887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:06.916156: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6471800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-02 14:40:06.916201: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-02 14:40:06.916479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:06.917369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-02 14:40:06.917443: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 14:40:06.917502: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 14:40:06.917544: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-02 14:40:06.917585: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-02 14:40:06.917624: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-02 14:40:06.917670: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-02 14:40:06.917711: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-02 14:40:06.917840: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:06.918839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:06.919700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-10-02 14:40:06.919770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-02 14:40:10.307455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-02 14:40:10.307518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-10-02 14:40:10.307551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-10-02 14:40:10.307902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:10.308914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-02 14:40:10.309678: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-02 14:40:10.309736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14320 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# > Summary of the model :
# Model: "model_1"
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# frames_input (InputLayer)                                      [(None, 31, 224, 224, 3)]                               0
# ____________________________________________________________________________________________________________________________________________
# frames_CNN (TimeDistributed)                                   (None, 31, 14, 14, 512)                                 9404992
# ____________________________________________________________________________________________________________________________________________
# bidirectional (Bidirectional)                                  (None, 31, 14, 14, 512)                                 14157824
# ____________________________________________________________________________________________________________________________________________
# ElementWiseMaxPooling (Lambda)                                 (None, 14, 14, 512)                                     0
# ____________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                                   (None, 7, 7, 512)                                       0
# ____________________________________________________________________________________________________________________________________________
# flatten (Flatten)                                              (None, 25088)                                           0
# ____________________________________________________________________________________________________________________________________________
# dense (Dense)                                                  (None, 1000)                                            25089000
# ____________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                                (None, 256)                                             256256
# ____________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                                (None, 10)                                              2570
# ____________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                                (None, 2)                                               22
# ============================================================================================================================================
# Total params: 48,910,664
# Trainable params: 48,910,664
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________
# > Optimizer :  {'name': 'Adam', 'learning_rate': 1e-06, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': True}
# > plotting the model architecture and saving at  model_architecture.png
# Epoch 1/50
# 2020-10-02 14:40:42.587985: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-02 14:40:47.728363: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 800/800 [==============================] - 878s 1s/step - loss: 0.3514 - acc: 0.8675 - val_loss: 0.3574 - val_acc: 0.8325
# Epoch 2/50
# 800/800 [==============================] - 872s 1s/step - loss: 0.3712 - acc: 0.8494 - val_loss: 0.3307 - val_acc: 0.8675
# Epoch 3/50
# 800/800 [==============================] - 847s 1s/step - loss: 0.3480 - acc: 0.8625 - val_loss: 0.3283 - val_acc: 0.8525
# Epoch 4/50
# 800/800 [==============================] - 857s 1s/step - loss: 0.3179 - acc: 0.8838 - val_loss: 0.3428 - val_acc: 0.8525
# Epoch 5/50
# 800/800 [==============================] - 847s 1s/step - loss: 0.3211 - acc: 0.8769 - val_loss: 0.3395 - val_acc: 0.8475
# Epoch 6/50
# 800/800 [==============================] - 847s 1s/step - loss: 0.3200 - acc: 0.8781 - val_loss: 0.3479 - val_acc: 0.8450
# Epoch 7/50
# 800/800 [==============================] - 848s 1s/step - loss: 0.3114 - acc: 0.8850 - val_loss: 0.3307 - val_acc: 0.8575
# Epoch 8/50
# 800/800 [==============================] - 847s 1s/step - loss: 0.3081 - acc: 0.8869 - val_loss: 0.3422 - val_acc: 0.8400
# Epoch 9/50
# 800/800 [==============================] - 849s 1s/step - loss: 0.3147 - acc: 0.8850 - val_loss: 0.3633 - val_acc: 0.8300
# Epoch 10/50
# 800/800 [==============================] - 850s 1s/step - loss: 0.3117 - acc: 0.8881 - val_loss: 0.3316 - val_acc: 0.8500
# Epoch 11/50
# 800/800 [==============================] - 853s 1s/step - loss: 0.3159 - acc: 0.8863 - val_loss: 0.3500 - val_acc: 0.8400
# Epoch 12/50
# 800/800 [==============================] - 860s 1s/step - loss: 0.3103 - acc: 0.8819 - val_loss: 0.3466 - val_acc: 0.8475
# Epoch 13/50
# 800/800 [==============================] - 854s 1s/step - loss: 0.2989 - acc: 0.8938 - val_loss: 0.3509 - val_acc: 0.8525
# Epoch 14/50
# 800/800 [==============================] - 853s 1s/step - loss: 0.3113 - acc: 0.8800 - val_loss: 0.3372 - val_acc: 0.8650
# Epoch 15/50
# 800/800 [==============================] - 853s 1s/step - loss: 0.2963 - acc: 0.8969 - val_loss: 0.3531 - val_acc: 0.8525
# Epoch 16/50
# 800/800 [==============================] - 846s 1s/step - loss: 0.3029 - acc: 0.8831 - val_loss: 0.3334 - val_acc: 0.8500
# Epoch 17/50
# 800/800 [==============================] - 855s 1s/step - loss: 0.3022 - acc: 0.8863 - val_loss: 0.3339 - val_acc: 0.8550
# Epoch 18/50
# 800/800 [==============================] - 858s 1s/step - loss: 0.2931 - acc: 0.8988 - val_loss: 0.3335 - val_acc: 0.8500
# Epoch 19/50
# 800/800 [==============================] - 857s 1s/step - loss: 0.2893 - acc: 0.9025 - val_loss: 0.3817 - val_acc: 0.8200
# Epoch 20/50
# 800/800 [==============================] - 852s 1s/step - loss: 0.2885 - acc: 0.9056 - val_loss: 0.3373 - val_acc: 0.8575
# Epoch 21/50
# 310/800 [==========>...................] - ETA: 7:33 - loss: 0.2535 - acc: 0.9129

# %%
# save preprocessed data in google drive using the following cells

# %%
import os
os.chdir('/content')
# !tar cvf rwf2000processed32framesTest.tar violenceDetection/rwf2000/processed/test
# !cp -r /content/rwf2000processed32framesTest.tar /gdrive/'My Drive'/THESIS/Data/data

# %%
import os
os.chdir('/content')
# !tar cvf rwf2000processed32framesTrainFight.tar violenceDetection/rwf2000/processed/train/fight 
# !split -b 4G rwf2000processed32framesTrainFight.tar "rwf2000processed32framesTrainFight.tar-"

# %%
import os
pt1 = "/content/rwf2000processed32framesTrainFight.tar-aa"
pt2 = "/content/rwf2000processed32framesTrainFight.tar-ab"
print(os.path.getsize(pt1))
print(os.path.getsize(pt2))
# Out:
# 4294967296
# 3570202624

# %%
# !cp -r /content/rwf2000processed32framesTrainFight.tar-aa /gdrive/'My Drive'/THESIS/Data/data
# !rm /content/rwf2000processed32framesTrainFight.tar-aa
# !cp -r /content/rwf2000processed32framesTrainFight.tar-ab /gdrive/'My Drive'/THESIS/Data/data
# !rm /content/rwf2000processed32framesTrainFight.tar-ab

# %%
import os
os.chdir('/content')
# !tar cvf rwf2000processed32framesTrainNonFight.tar violenceDetection/rwf2000/processed/train/nonFight 
# !split -b 4G rwf2000processed32framesTrainNonFight.tar "rwf2000processed32framesTrainNonFight.tar-"

# %%
import os
pt1 = "/content/rwf2000processed32framesTrainNonFight.tar-aa"
pt2 = "/content/rwf2000processed32framesTrainNonFight.tar-ab"
print(os.path.getsize(pt1))
print(os.path.getsize(pt2))
# Out:
# 4294967296
# 3570182144

# %%
# !cp -r /content/rwf2000processed32framesTrainNonFight.tar-aa /gdrive/'My Drive'/THESIS/Data/data
# !rm /content/rwf2000processed32framesTrainNonFight.tar-aa
# !cp -r /content/rwf2000processed32framesTrainNonFight.tar-ab /gdrive/'My Drive'/THESIS/Data/data
# !rm /content/rwf2000processed32framesTrainNonFight.tar-ab

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
# !pip install pytest-shutil

# %%
# plot model architecture
dot_img_file = '/tmp/model_1.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
# to get more RAM
a = []
while(1):
    a.append(1)
